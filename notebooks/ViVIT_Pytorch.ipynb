# %% [markdown]
# <a href="https://colab.research.google.com/github/djsg2021utec/TESIS_MAESTRIA/blob/main/ViVIT_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

# %pip install ffmpeg
from tqdm import tqdm
import time
import os
from base64 import b64encode
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from IPython.display import HTML
from base64 import b64encode
import glob
from random import shuffle
import tensorflow as tf
import torch
import shutil
import sys
from torch.utils.data import DataLoader, TensorDataset, random_split
import ffmpeg


# %pip install tensorboard torchvision
# from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### Extraer los videos

# %%
# %%capture
# @title Descargar bases de datos
# @markdown ## **Real World Fights 2000**

# @markdown #### Una base de datos con 2000 videos capturados por medio de cámaras de videovigilancia en el mundo real. Introducido por [Cheng 2019](https://paperswithcode.com/paper/rwf-2000-an-open-large-scale-video-database).

# Enlace del repositorio donde está alojandos los datos
# https://github.com/mchengny/RWF2000-Video-Database-for-Violence-Detection

# @markdown ## **Ingrese las direcciones de los ZIP** :
RWF_2000_1_url = "https://drive.google.com/uc?id=1nQ9IR3cGc4NEDOXhPQ89id8je8Uj2VUc" # @param {type:"string"}
RWF_2000_2_url = "https://drive.google.com/uc?id=1w9G_Z7gkXZzK4DImdI8wanyjs22fQARO" # @param {type:"string"}
RWF_2000_3_url = "https://drive.google.com/uc?id=15LhjavoUsLS01CPkc3qav0rJxBc9d4nl" # @param {type:"string"}
# @markdown ---


# ********************************************************************
# Descargando los fragmentos del archivo ZIP de la data RWF-2000.zip
# ********************************************************************
if not os.path.exists('/content/RWF-2000'):
  download_links = [
      RWF_2000_1_url,
      RWF_2000_2_url,
      RWF_2000_3_url
  ]

  for link in tqdm(download_links, desc="Descargando fragmentos"):
      # !gdown {link}
  # ********************************************************************
  # Juntando los fragmentos del archivo ZIP de la data RWF-2000.zip
  # ********************************************************************
  # !cat RWF-2000.zip.001 RWF-2000.zip.002 RWF-2000.zip.003 > RWF-2000.zip

  # Eliminando los fragmentos
  for fragment in tqdm(["RWF-2000.zip.001", "RWF-2000.zip.002", "RWF-2000.zip.003"], desc="Eliminando fragmentos"):
      # !rm /content/{fragment}

  # Descomprimiendo los archivos en el directorio RWF-2000
  # !unzip "/content/RWF-2000.zip" -d "/content/"

  # Eliminando RWF-2000.zip
  # !rm /content/RWF-2000.zip

  # Asegurar que la memoria RAM se liberó
  import gc
  gc.collect()

  time.sleep(10)

# ******************************************************************
# Se crea un dataframe para manejar fácilmente los datos de RWF-2000
# ******************************************************************
carpeta = '/content/RWF-2000'
lista_carpetas_avi = [
    {'ruta': f'{carpeta}/train/Fight', 'data': 'train', 'etiqueta':'Fight'},
    {'ruta': f'{carpeta}/train/NonFight', 'data': 'train', 'etiqueta':'NonFight'},
    {'ruta': f'{carpeta}/val/Fight', 'data': 'val', 'etiqueta':'Fight'},
    {'ruta': f'{carpeta}/val/NonFight', 'data': 'val', 'etiqueta':'NonFight'}
]
lista_archivos_avi = []
for carpeta in lista_carpetas_avi:
  ruta_carpeta=carpeta['ruta']
  tipo_data =carpeta['data']
  etiqueta_data =carpeta['etiqueta']
  for filename in os.listdir(ruta_carpeta):
      if filename.endswith(".avi"):
        registro_archivo = {'ruta': f'{ruta_carpeta}/{filename}', 'data': f'{tipo_data}', 'etiqueta':f'{etiqueta_data}'}
        lista_archivos_avi.append(registro_archivo)

videos_RWF2000_df = pd.DataFrame(lista_archivos_avi)
print("Se creó el dataframe: videos_RWF2000_df")

# %% [markdown]
# ### Resumen de las bases de datos

# %%
# @markdown **Funciones de los histogramas**
# Histograma de los frames que tienen los videos
import pandas as pd
import matplotlib.pyplot as plt

fps = True # @param {type:"boolean"}
total_frames = True # @param {type:"boolean"}

def histograms_in_videos(videos_df):
    list_fps = []
    list_total_frames = []
    number_items = videos_df.shape[0]  # Aquí cambié 'videos_RWF2000_df' por 'videos_df'

    for i in range(number_items):
        video_path = videos_df['ruta'][i]
        cap = cv2.VideoCapture(video_path)
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        list_fps.append(fps)
        list_total_frames.append(total_frames)

    return list_fps,list_total_frames

def plot_histograms(list_fps, list_total_frames, database_name = "RWF_2000"):
    """Función para graficar histogramas de FPS y número total de frames."""

    # Crear una figura y dos subplots
    fig, axs = plt.subplots(2, 1, figsize=(10, 8))

    # Datos y configuraciones para cada subplot
    data_list = [list_fps, list_total_frames]
    titles = [f'Histograma de FPS en videos de la data {database_name}', f'Histograma de Número total de frames de la data {database_name}']
    xlabels = ['FPS', 'Número total de frames']
    ylabels = ['Número de videos', 'Número de videos']

    # Bucle para crear y configurar cada histograma
    for i, ax in enumerate(axs):
        ax.hist(data_list[i], bins=30, edgecolor='black', alpha=0.7)
        ax.set_title(titles[i])
        ax.set_xlabel(xlabels[i])
        ax.set_ylabel(ylabels[i])
        ax.grid(True, which='both', linestyle='--', linewidth=0.5)

    # Ajustar el espacio entre los subplots
    plt.tight_layout()

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# #### RWF-2000

# %%
# Descripción general de los datos
videos_RWF2000_df.describe()
# Out:
#                                                    ruta   data etiqueta
# count                                              2000   2000     2000
# unique                                             2000      2        2
# top     /content/RWF-2000/train/Fight/GhZRf4GIw0w_0.avi  train    Fight
# freq                                                  1   1600     1000

# %%
import matplotlib.pyplot as plt
list_fps,list_total_frames = histograms_in_videos(videos_RWF2000_df)
plot_histograms(list_fps, list_total_frames)

# %%
# **********************************************************************
# Se toma una muestra con una fracción de los datos del dataframe
# **********************************************************************

# Función para obtener un subconjunto aleatorio del DataFrame
def grupo_de_muestras(group, frac=0.10):
    return group.sample(frac=frac)

# Dividir el DataFrame según las variables 'etapa' y 'etiqueta' y aplicar la función grupo_de_muestras
muestra_RWF2000_df = videos_RWF2000_df.groupby(['data', 'etiqueta']).apply(grupo_de_muestras).reset_index(drop=True)
# Se elimina una variable que tiene muchas variables
del videos_RWF2000_df

muestra_RWF2000_df.describe()
# Out:
#                                                 ruta   data etiqueta
# count                                            200    200      200
# unique                                           200      2        2
# top     /content/RWF-2000/train/Fight/DHhyNrXr_1.avi  train    Fight
# freq                                               1    160      100

# %%
from IPython.display import HTML
from base64 import b64encode
import os,time

def show_video(video_path, video_width = 600):
  video_name = video_path.split('/')[-1].split('.')[0]
  while not os.path.exists(f"/content/{video_name}.mp4"):
    os.popen("ffmpeg -i '{input}' -ac 2 -b:v 2000k -c:a aac -c:v libx264 -b:a 160k -vprofile high -bf 0 -strict experimental -f mp4 '{output}.mp4'".format(input=video_path, output=f"/content/{video_name}"))
    time.sleep(10)
  video_file = open(f"/content/{video_name}.mp4", "rb").read()

  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

def delete_video(video_path):
  video_name = video_path.split('/')[-1].split('.')[0]
  video_to_eliminate_path= f"/content/{video_name}.mp4"
  print(f"Se está eliminando el video: {video_name}")
  os.remove(video_to_eliminate_path)

# %%
video_path = muestra_RWF2000_df[muestra_RWF2000_df["etiqueta"]=="Fight"]["ruta"].sample(1).to_list()[0]
show_video(video_path)
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>

# %%
delete_video(video_path)
# Out:
# Se está eliminando el video: xKq3hlefCUI_1

# %%
def generate_heatmaps(video_path):
    video_name = video_path.split("/")[-1:][0].split(".")[0]
    output_folder = f"/content/{video_name}"
    output_video_path = f"/content/{video_name}.mp4"
    cap = cv2.VideoCapture(video_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    frame_count = 0
    heatmap_frames = []

    ret, prev_frame = cap.read()
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(gray_frame, prev_gray)

        normalized_diff = (frame_diff / np.max(frame_diff) * 255).astype(np.uint8)
        heatmap_color = cv2.applyColorMap(normalized_diff, cv2.COLORMAP_JET)

        heatmap_path = os.path.join(output_folder, f'heatmap_{frame_count}.png')
        cv2.imwrite(heatmap_path, heatmap_color)
        heatmap_frames.append(heatmap_path)

        prev_gray = gray_frame
        frame_count += 1

    cap.release()

    # Convertir imágenes del heatmap en un video mp4
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    for i in range(frame_count):
        frame = cv2.imread(heatmap_frames[i])
        out.write(frame)
    out.release()

# Generar heatmaps y un video mp4

# %%
generate_heatmaps(video_path)

# %%
import os
import subprocess
import ffmpeg
video_name = video_path.split("/")[-1:][0].split(".")[0]
output_video_path = f"{video_name}.mp4"
compressed_video_path = f"{video_name}_compressed.mp4"
command = [
    'ffmpeg',
    '-i', output_video_path,
    '-vcodec', 'h264',
    '-acodec', 'mp2',
    compressed_video_path
]
subprocess.run(command)
# Out:
# CompletedProcess(args=['ffmpeg', '-i', 'bW2vHhYbzHM_0.mp4', '-vcodec', 'h264', '-acodec', 'mp2', 'bW2vHhYbzHM_0_compressed.mp4'], returncode=0)

# %%
import os
import subprocess
import ffmpeg
video_width = 500
path=f"/content/{compressed_video_path}"
video_file = open(path,"rb").read()
video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")
# Out:
# <video width=500 controls><source src="data:video/mp4;base64,..."></video>

# %% [markdown]
# ## Extrayendo la zona de calor más importante

# %%
import cv2
import numpy as np
import os

def contornos_heatmaps(video_path):
    video_name = video_path.split("/")[-1:][0].split(".")[0]
    output_folder = f"/content/{video_name}_contornos"
    output_video_path = f"/content/{video_name}_contornos.mp4"

    cap = cv2.VideoCapture(video_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    frame_count = 0
    heatmap_frames = []

    ret, prev_frame = cap.read()
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_diff = cv2.absdiff(gray_frame, prev_gray)

        normalized_diff = (frame_diff / np.max(frame_diff) * 255).astype(np.uint8)
        heatmap_color = cv2.applyColorMap(normalized_diff, cv2.COLORMAP_JET)

        _, thresholded = cv2.threshold(normalized_diff, np.max(normalized_diff) * 0.5, 255, cv2.THRESH_BINARY)

        contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        if contours:
            max_contour = max(contours, key=cv2.contourArea)
            if cv2.contourArea(max_contour) > 50:  # Puedes ajustar este umbral
                x, y, w, h = cv2.boundingRect(max_contour)
                cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                cv2.drawContours(heatmap_color, [max_contour], -1, (0, 255, 0), 3)

        heatmap_path = os.path.join(output_folder, f'heatmap_{frame_count}.png')
        cv2.imwrite(heatmap_path, heatmap_color)
        heatmap_frames.append(heatmap_path)

        prev_gray = gray_frame
        frame_count += 1

    cap.release()

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    for i in range(frame_count):
        frame = cv2.imread(heatmap_frames[i])
        out.write(frame)

    out.release()

# %%
contornos_heatmaps(video_path)

# %%
video_name = video_path.split("/")[-1:][0].split(".")[0]
output_video_path = f"{video_name}_contornos.mp4"
compressed_video_path = f"{video_name}_contornos_compressed.mp4"

command = [
    'ffmpeg',
    '-i', output_video_path,
    '-vcodec', 'h264',
    '-acodec', 'mp2',
    compressed_video_path
]
subprocess.run(command)
# Out:
# CompletedProcess(args=['ffmpeg', '-i', 'Am9mUxPTvK4_1_contornos.mp4', '-vcodec', 'h264', '-acodec', 'mp2', 'Am9mUxPTvK4_1_contornos_compressed.mp4'], returncode=1)

# %%
import os
import subprocess
import ffmpeg
video_width = 500
path=compressed_video_path
video_file = open(path,"rb").read()
video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")
# Out:
# <video width=500 controls><source src="data:video/mp4;base64,..."></video>

# %%
def obtener_tensor(video_paths):
    videos = []
    for video_path in video_paths:
        # Abrir el video
        cap = cv2.VideoCapture(video_path)

        # Obtener las características del video
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        duration = num_frames / fps

        # Definir la resolución y el número de canales deseados
        target_resolution = (224, 224)
        target_channels = 3

        # Inicializar un tensor para almacenar los frames redimensionados
        video_tensor = torch.empty((num_frames, target_channels, target_resolution[1], target_resolution[0]), dtype=torch.float32)

        frame_idx = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break

            # Número de canales deseado
            if frame.shape[-1] != target_channels:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convertir a RGB si es necesario

            # Redimensionar el frame a la resolución deseada usando torch.nn.functional.interpolate
            frame = torch.from_numpy(frame).permute(2, 0, 1).float() / 255.0  # Cambiar formato y escalar
            frame = torch.nn.functional.interpolate(frame.unsqueeze(0), size=target_resolution, mode='bilinear', align_corners=False)
            frame = frame.squeeze(0)

            # Almacenar el frame en el tensor
            video_tensor[frame_idx] = frame
            frame_idx += 1

        # Liberar los recursos
        cap.release()

        # Agregar el tensor del video a la lista
        videos.append(video_tensor)

    tensor_torch = torch.stack(videos, dim=0)
    # Imprimir las dimensiones del tensor resultante
    print("Dimensiones del tensor resultante:", tensor_torch.shape)
    return tensor_torch


def obtener_labels(video_labels):
  # Crear un diccionario de mapeo de etiquetas a valores binarios (1 y 0)
  label_map = {'Fight': 1, 'NonFight': 0}

  # Convertir las etiquetas a valores binarios usando el mapeo
  binary_labels = [label_map[label] for label in video_labels]

  # Crear un tensor de PyTorch a partir de la lista de valores binarios
  tensor_labels = torch.tensor(binary_labels, dtype=torch.float32).to(torch.long)

  # Imprimir las dimensiones del tensor resultante
  print("Dimensiones del tensor resultante:", tensor_labels.shape)
  return tensor_labels

# %%
train_video_paths = list(muestra_RWF2000_df[muestra_RWF2000_df['data']=='train']['ruta'])
train_video_labels = list(muestra_RWF2000_df[muestra_RWF2000_df['data']=='train']['etiqueta'])
# tensor_data = obtener_tensor()
train_videos = obtener_tensor(train_video_paths)
train_labels = obtener_labels(train_video_labels)
# Out:
# Dimensiones del tensor resultante: torch.Size([160, 150, 3, 224, 224])
# Dimensiones del tensor resultante: torch.Size([160])

# %%
test_video_paths = list(muestra_RWF2000_df[muestra_RWF2000_df['data']=='val']['ruta'])
test_video_labels = list(muestra_RWF2000_df[muestra_RWF2000_df['data']=='val']['etiqueta'])
# tensor_data = obtener_tensor()
test_videos = obtener_tensor(test_video_paths)
test_labels = obtener_labels(test_video_labels)
# Out:
# Dimensiones del tensor resultante: torch.Size([40, 150, 3, 224, 224])
# Dimensiones del tensor resultante: torch.Size([40])

# %%
train_data=TensorDataset(train_videos, train_labels)
test_data=TensorDataset(test_videos, test_labels)

# %% [markdown]
# # Entrenar el modelo

# %%
# %pip install einops
from torch import nn, einsum
import torch
from einops.layers.torch import Rearrange
from einops import rearrange, repeat


class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn

    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)


class FSAttention(nn.Module):
    """Factorized Self-Attention"""

    def __init__(self, dim, heads=8, dim_head=64, dropout=0.):
        super().__init__()
        inner_dim = dim_head * heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim=-1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias=False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        b, n, _, h = *x.shape, self.heads
        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=h), qkv)

        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        attn = self.attend(dots)

        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)


class FDAttention(nn.Module):
    """Factorized Dot-product Attention"""

    def __init__(self, dim, nt, nh, nw, heads=8, dim_head=64, dropout=0.):
        super().__init__()
        inner_dim = dim_head * heads
        project_out = not (heads == 1 and dim_head == dim)

        self.nt = nt
        self.nh = nh
        self.nw = nw

        self.heads = heads
        self.scale = dim_head ** -0.5

        self.attend = nn.Softmax(dim=-1)
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias=False)

        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        b, n, d, h = *x.shape, self.heads

        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=h), qkv)
        qs, qt = q.chunk(2, dim=1)
        ks, kt = k.chunk(2, dim=1)
        vs, vt = v.chunk(2, dim=1)

        # Attention over spatial dimension
        qs = qs.view(b, h // 2, self.nt, self.nh * self.nw, -1)
        ks, vs = ks.view(b, h // 2, self.nt, self.nh * self.nw, -1), vs.view(b, h // 2, self.nt, self.nh * self.nw, -1)
        spatial_dots = einsum('b h t i d, b h t j d -> b h t i j', qs, ks) * self.scale
        sp_attn = self.attend(spatial_dots)
        spatial_out = einsum('b h t i j, b h t j d -> b h t i d', sp_attn, vs)

        # Attention over temporal dimension
        qt = qt.view(b, h // 2, self.nh * self.nw, self.nt, -1)
        kt, vt = kt.view(b, h // 2, self.nh * self.nw, self.nt, -1), vt.view(b, h // 2, self.nh * self.nw, self.nt, -1)
        temporal_dots = einsum('b h s i d, b h s j d -> b h s i j', qt, kt) * self.scale
        temporal_attn = self.attend(temporal_dots)
        temporal_out = einsum('b h s i j, b h s j d -> b h s i d', temporal_attn, vt)

        # return self.to_out(out)


class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout=0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)


class FSATransformerEncoder(nn.Module):
    """Factorized Self-Attention Transformer Encoder"""

    def __init__(self, dim, depth, heads, dim_head, mlp_dim, nt, nh, nw, dropout=0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        self.nt = nt
        self.nh = nh
        self.nw = nw

        for _ in range(depth):
            self.layers.append(nn.ModuleList(
                [PreNorm(dim, FSAttention(dim, heads=heads, dim_head=dim_head, dropout=dropout)),
                 PreNorm(dim, FSAttention(dim, heads=heads, dim_head=dim_head, dropout=dropout)),
                 PreNorm(dim, FeedForward(dim, mlp_dim, dropout=dropout))
                 ]))

    def forward(self, x):

        b = x.shape[0]
        x = torch.flatten(x, start_dim=0, end_dim=1)  # extract spatial tokens from x

        for sp_attn, temp_attn, ff in self.layers:
            sp_attn_x = sp_attn(x) + x  # Spatial attention

            # Reshape tensors for temporal attention
            sp_attn_x = sp_attn_x.chunk(b, dim=0)
            sp_attn_x = [temp[None] for temp in sp_attn_x]
            sp_attn_x = torch.cat(sp_attn_x, dim=0).transpose(1, 2)
            sp_attn_x = torch.flatten(sp_attn_x, start_dim=0, end_dim=1)

            temp_attn_x = temp_attn(sp_attn_x) + sp_attn_x  # Temporal attention

            x = ff(temp_attn_x) + temp_attn_x  # MLP

            # Again reshape tensor for spatial attention
            x = x.chunk(b, dim=0)
            x = [temp[None] for temp in x]
            x = torch.cat(x, dim=0).transpose(1, 2)
            x = torch.flatten(x, start_dim=0, end_dim=1)

        # Reshape vector to [b, nt*nh*nw, dim]
        x = x.chunk(b, dim=0)
        x = [temp[None] for temp in x]
        x = torch.cat(x, dim=0)
        x = torch.flatten(x, start_dim=1, end_dim=2)
        return x


class FDATransformerEncoder(nn.Module):
    """Factorized Dot-product Attention Transformer Encoder"""

    def __init__(self, dim, depth, heads, dim_head, mlp_dim, nt, nh, nw, dropout=0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        self.nt = nt
        self.nh = nh
        self.nw = nw

        for _ in range(depth):
            self.layers.append(
                PreNorm(dim, FDAttention(dim, nt, nh, nw, heads=heads, dim_head=dim_head, dropout=dropout)))

    def forward(self, x):
        for attn in self.layers:
            x = attn(x) + x

        return x


class ViViTBackbone(nn.Module):
    """ Model-3 backbone of ViViT """

    def __init__(self, t, h, w, patch_t, patch_h, patch_w, num_classes, dim, depth, heads, mlp_dim, dim_head=3,
                 channels=3, mode='tubelet', device='cuda', emb_dropout=0., dropout=0., model=3):
        super().__init__()

        assert t % patch_t == 0 and h % patch_h == 0 and w % patch_w == 0, "Video dimensions should be divisible by " \
                                                                           "tubelet size "

        self.T = t
        self.H = h
        self.W = w
        self.channels = channels
        self.t = patch_t
        self.h = patch_h
        self.w = patch_w
        self.mode = mode
        self.device = device

        self.nt = self.T // self.t
        self.nh = self.H // self.h
        self.nw = self.W // self.w

        tubelet_dim = self.t * self.h * self.w * channels

        self.to_tubelet_embedding = nn.Sequential(
            Rearrange('b c (t pt) (h ph) (w pw) -> b t (h w) (pt ph pw c)', pt=self.t, ph=self.h, pw=self.w),
            nn.Linear(tubelet_dim, dim)
        )

        # repeat same spatial position encoding temporally
        self.pos_embedding = nn.Parameter(torch.randn(1, 1, self.nh * self.nw, dim)).repeat(1, self.nt, 1, 1)

        self.dropout = nn.Dropout(emb_dropout)

        if model == 3:
            self.transformer = FSATransformerEncoder(dim, depth, heads, dim_head, mlp_dim,
                                                     self.nt, self.nh, self.nw, dropout)
        elif model == 4:
            assert heads % 2 == 0, "Number of heads should be even"
            self.transformer = FDATransformerEncoder(dim, depth, heads, dim_head, mlp_dim,
                                                     self.nt, self.nh, self.nw, dropout)

        self.to_latent = nn.Identity()

        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, x):
        """ x is a video: (b, C, T, H, W) """

        tokens = self.to_tubelet_embedding(x)

        tokens += self.pos_embedding.to(device)
        tokens = self.dropout(tokens)

        x = self.transformer(tokens)
        x = x.mean(dim=1)

        x = self.to_latent(x)
        return self.mlp_head(x)


# if __name__ == '__main__':
#     device = torch.device('cuda')
#     x = torch.rand(32, 3, 32, 64, 64).to(device)

#     vivit = ViViTBackbone(32, 64, 64, 8, 4, 4, 10, 512, 6, 10, 8, model=3).to(device)
#     out = vivit(x)
#     print(out)
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0

# %%
### Métricas de evaluación
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve


# Funciones para métricas
def accuracy(y_pred, y_true):
    _, predicted = torch.max(y_pred, 1)
    correct = (predicted == y_true).float()
    return correct.sum() / len(correct)

def average_precision(y_pred, y_true):
    y_pred = torch.sigmoid(y_pred[:, 1]).detach().cpu().numpy()  # Suponemos que el índice 1 es la clase positiva
    y_true = y_true.cpu().numpy()
    return average_precision_score(y_true, y_pred)

def roc_curve_values(y_pred, y_true):
    y_pred = torch.sigmoid(y_pred[:, 1]).detach().cpu().numpy()  # Suponemos que el índice 1 es la clase positiva
    y_true = y_true.cpu().numpy()
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    return fpr, tpr, thresholds

# %%
class EarlyStopping:
    def __init__(self, patience=7, delta=0.05, verbose=False):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.stop = False
        self.delta = delta  # Cambio mínimo requerido (5% en este caso)

    def step(self, accuracy):
        score = accuracy
        if self.best_score is None:
            self.best_score = score
        # Si la mejora en precisión es menor que delta
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop = True
                if self.verbose:
                    print(f"EarlyStopping activated. Best accuracy: {self.best_score:.4f}")
        else:
            self.best_score = score
            self.counter = 0

# %%
# Configuración del modelo y del dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Desactiva el benchmarking de cuDNN
torch.backends.cudnn.benchmark = False

num_epochs = 200
lr = 0.001
weight_decay= 0.0001
v = ViViTBackbone(
    t=150,
    h=224,
    w=224,
    patch_t=30,
    patch_h=14,
    patch_w=14,
    num_classes=2,  # Solo hay 2 clases: violencia y no violencia
    dim=128, #224
    depth=6,
    heads=10,
    mlp_dim=5,
    model=3
).to(device)

parameters = filter(lambda p: p.requires_grad, v.parameters())
parameters = sum([np.prod(p.size()) for p in parameters]) / 1_000_000
print('Número de parámetros entrenables: %.3fM' % parameters)

early_stopping = EarlyStopping(patience=10, delta=0.1, verbose=True)

# Dividir en entrenamiento y prueba
# train_data = TensorDataset(train_videos, train_labels)
# test_data = TensorDataset(test_videos, test_labels)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32)

# Función de pérdida y optimizador
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(v.parameters(), lr=lr, weight_decay=weight_decay)

# Entrenamiento
loss_values = []
val_loss_values = []

train_accuracy_values = []
val_accuracy_values = []

y_true = np.array([])
y_pred = np.array([])

out_epochs = 0

for epoch in range(num_epochs):
    v.train()
    avg_loss = 0
    num_batches = 0

    train_correct = 0
    train_total = 0

    for videos_batch, labels_batch in train_loader:
        videos_batch, labels_batch = videos_batch.to(device), labels_batch.to(device)
        videos_batch=videos_batch.permute(0, 2, 1, 3, 4)
        # Propagación hacia adelante

        predictions = v(videos_batch)

        loss = criterion(predictions, labels_batch)

        # Propagación hacia atrás y optimización
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        avg_loss += loss.item()
        num_batches += 1

        _, train_predicted = torch.max(predictions.data, 1)
        train_total += labels_batch.size(0)
        train_correct += (train_predicted == labels_batch).sum().item()

    avg_loss /= num_batches
    loss_values.append(avg_loss)

    train_accuracy = 100 * train_correct / train_total
    train_accuracy_values.append(train_accuracy)



    # Evaluación en el conjunto de validación
    v.eval()
    val_loss = 0
    val_batches = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for val_videos_batch, val_labels_batch in test_loader:
            val_videos_batch, val_labels_batch = val_videos_batch.to(device), val_labels_batch.to(device)
            val_videos_batch=val_videos_batch.permute(0, 2, 1, 3, 4)
            val_predictions = v(val_videos_batch)
            val_loss_batch = criterion(val_predictions, val_labels_batch)
            val_loss += val_loss_batch.item()
            val_batches += 1
            _, predicted = torch.max(val_predictions.data, 1)
            total += val_labels_batch.size(0)
            correct += (predicted == val_labels_batch).sum().item()

            val_batches += 1

    val_loss /= val_batches
    val_loss_values.append(val_loss)

    val_accuracy = 100 * correct / total
    val_accuracy_values.append(val_accuracy)


    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss:.4f}, Validation Loss: {val_loss:.4f}, Train Acc: {train_accuracy:.2f}, Validation Acc: {val_accuracy:.2f}%")
    #Llamada al EarlyStopping
    # early_stopping.step(train_accuracy)
    # if early_stopping.stop:
    #     print("Stopping training early!")
    #     break
    # out_epochs += 1

del videos_batch,labels_batch, val_videos_batch, val_labels_batch
# Out:
# Número de parámetros entrenables: 2.458M
# Epoch [1/200], Train Loss: 1.0589, Validation Loss: 0.4647, Train Acc: 53.12, Validation Acc: 50.00%
# Epoch [2/200], Train Loss: 0.7251, Validation Loss: 0.3309, Train Acc: 52.08, Validation Acc: 50.00%
# Epoch [3/200], Train Loss: 0.7321, Validation Loss: 0.3348, Train Acc: 50.00, Validation Acc: 50.00%
# Epoch [4/200], Train Loss: 0.6958, Validation Loss: 0.3768, Train Acc: 54.17, Validation Acc: 50.00%
# Epoch [5/200], Train Loss: 0.7075, Validation Loss: 0.3453, Train Acc: 50.52, Validation Acc: 50.00%
# Epoch [6/200], Train Loss: 0.6930, Validation Loss: 0.3294, Train Acc: 52.08, Validation Acc: 50.00%
# Epoch [7/200], Train Loss: 0.6924, Validation Loss: 0.3383, Train Acc: 49.48, Validation Acc: 79.17%
# Epoch [8/200], Train Loss: 0.6888, Validation Loss: 0.3409, Train Acc: 57.29, Validation Acc: 81.25%
# Epoch [9/200], Train Loss: 0.6915, Validation Loss: 0.3299, Train Acc: 52.08, Validation Acc: 64.58%
# Epoch [10/200], Train Loss: 0.6859, Validation Loss: 0.3381, Train Acc: 58.85, Validation Acc: 81.25%
# Epoch [11/200], Train Loss: 0.6823, Validation Loss: 0.3238, Train Acc: 59.38, Validation Acc: 79.17%
# Epoch [12/200], Train Loss: 0.6788, Validation Loss: 0.3179, Train Acc: 58.85, Validation Acc: 79.17%
# Epoch [13/200], Train Loss: 0.6739, Validation Loss: 0.3187, Train Acc: 60.42, Validation Acc: 79.17%
# Epoch [14/200], Train Loss: 0.6714, Validation Loss: 0.3048, Train Acc: 60.42, Validation Acc: 79.17%
# Epoch [15/200], Train Loss: 0.6647, Validation Loss: 0.2998, Train Acc: 59.90, Validation Acc: 77.08%
# Epoch [16/200], Train Loss: 0.6609, Validation Loss: 0.2927, Train Acc: 62.50, Validation Acc: 79.17%
# Epoch [17/200], Train Loss: 0.6658, Validation Loss: 0.2757, Train Acc: 56.77, Validation Acc: 79.17%
# Epoch [18/200], Train Loss: 0.6551, Validation Loss: 0.2783, Train Acc: 61.46, Validation Acc: 81.25%
# Epoch [19/200], Train Loss: 0.6508, Validation Loss: 0.2757, Train Acc: 60.42, Validation Acc: 79.17%
# Epoch [20/200], Train Loss: 0.6454, Validation Loss: 0.2648, Train Acc: 61.98, Validation Acc: 79.17%
# Epoch [21/200], Train Loss: 0.6408, Validation Loss: 0.2678, Train Acc: 63.54, Validation Acc: 79.17%
# Epoch [22/200], Train Loss: 0.6406, Validation Loss: 0.2760, Train Acc: 61.98, Validation Acc: 79.17%
# Epoch [23/200], Train Loss: 0.6380, Validation Loss: 0.2619, Train Acc: 64.58, Validation Acc: 77.08%
# Epoch [24/200], Train Loss: 0.6355, Validation Loss: 0.2801, Train Acc: 63.54, Validation Acc: 79.17%
# Epoch [25/200], Train Loss: 0.6254, Validation Loss: 0.2603, Train Acc: 64.06, Validation Acc: 79.17%
# Epoch [26/200], Train Loss: 0.6230, Validation Loss: 0.2613, Train Acc: 64.58, Validation Acc: 79.17%
# Epoch [27/200], Train Loss: 0.6173, Validation Loss: 0.2599, Train Acc: 62.50, Validation Acc: 77.08%
# Epoch [28/200], Train Loss: 0.6058, Validation Loss: 0.2702, Train Acc: 67.19, Validation Acc: 79.17%
# Epoch [29/200], Train Loss: 0.6016, Validation Loss: 0.2474, Train Acc: 66.15, Validation Acc: 70.83%
# Epoch [30/200], Train Loss: 0.5835, Validation Loss: 0.2581, Train Acc: 66.67, Validation Acc: 79.17%
# Epoch [31/200], Train Loss: 0.5745, Validation Loss: 0.2583, Train Acc: 68.75, Validation Acc: 75.00%
# Epoch [32/200], Train Loss: 0.5883, Validation Loss: 0.2729, Train Acc: 63.02, Validation Acc: 79.17%
# Epoch [33/200], Train Loss: 0.5601, Validation Loss: 0.2499, Train Acc: 66.67, Validation Acc: 70.83%
# Epoch [34/200], Train Loss: 0.5495, Validation Loss: 0.2709, Train Acc: 70.31, Validation Acc: 79.17%
# Epoch [35/200], Train Loss: 0.5325, Validation Loss: 0.2529, Train Acc: 73.96, Validation Acc: 81.25%
# Epoch [36/200], Train Loss: 0.5194, Validation Loss: 0.2694, Train Acc: 72.92, Validation Acc: 77.08%
# Epoch [37/200], Train Loss: 0.5149, Validation Loss: 0.2708, Train Acc: 70.31, Validation Acc: 77.08%
# Epoch [38/200], Train Loss: 0.5204, Validation Loss: 0.2905, Train Acc: 70.83, Validation Acc: 79.17%
# Epoch [39/200], Train Loss: 0.5258, Validation Loss: 0.2832, Train Acc: 70.83, Validation Acc: 54.17%
# Epoch [40/200], Train Loss: 0.5413, Validation Loss: 0.2565, Train Acc: 68.75, Validation Acc: 68.75%
# Epoch [41/200], Train Loss: 0.4848, Validation Loss: 0.3233, Train Acc: 73.96, Validation Acc: 79.17%
# Epoch [42/200], Train Loss: 0.5380, Validation Loss: 0.3309, Train Acc: 72.40, Validation Acc: 79.17%
# Epoch [43/200], Train Loss: 0.5220, Validation Loss: 0.2650, Train Acc: 70.31, Validation Acc: 64.58%
# Epoch [44/200], Train Loss: 0.4781, Validation Loss: 0.2836, Train Acc: 72.40, Validation Acc: 68.75%
# Epoch [45/200], Train Loss: 0.4637, Validation Loss: 0.3117, Train Acc: 75.52, Validation Acc: 75.00%
# Epoch [46/200], Train Loss: 0.4653, Validation Loss: 0.2877, Train Acc: 72.92, Validation Acc: 54.17%
# Epoch [47/200], Train Loss: 0.5121, Validation Loss: 0.3896, Train Acc: 72.92, Validation Acc: 75.00%
# Epoch [48/200], Train Loss: 0.5374, Validation Loss: 0.2541, Train Acc: 67.71, Validation Acc: 60.42%
# Epoch [49/200], Train Loss: 0.4882, Validation Loss: 0.2843, Train Acc: 75.52, Validation Acc: 79.17%
# Epoch [50/200], Train Loss: 0.4701, Validation Loss: 0.2490, Train Acc: 71.35, Validation Acc: 56.25%
# Epoch [51/200], Train Loss: 0.4535, Validation Loss: 0.3007, Train Acc: 76.04, Validation Acc: 79.17%
# Epoch [52/200], Train Loss: 0.4246, Validation Loss: 0.2678, Train Acc: 77.60, Validation Acc: 75.00%
# Epoch [53/200], Train Loss: 0.4287, Validation Loss: 0.3265, Train Acc: 78.12, Validation Acc: 79.17%
# Epoch [54/200], Train Loss: 0.3992, Validation Loss: 0.2849, Train Acc: 78.12, Validation Acc: 62.50%
# Epoch [55/200], Train Loss: 0.4086, Validation Loss: 0.3001, Train Acc: 78.65, Validation Acc: 75.00%
# Epoch [56/200], Train Loss: 0.3938, Validation Loss: 0.2498, Train Acc: 79.17, Validation Acc: 62.50%
# Epoch [57/200], Train Loss: 0.4459, Validation Loss: 0.2289, Train Acc: 77.08, Validation Acc: 77.08%
# Epoch [58/200], Train Loss: 0.4237, Validation Loss: 0.2561, Train Acc: 78.65, Validation Acc: 79.17%
# Epoch [59/200], Train Loss: 0.4120, Validation Loss: 0.2588, Train Acc: 75.00, Validation Acc: 64.58%
# Epoch [60/200], Train Loss: 0.3881, Validation Loss: 0.3163, Train Acc: 81.77, Validation Acc: 79.17%
# Epoch [61/200], Train Loss: 0.3938, Validation Loss: 0.3082, Train Acc: 79.17, Validation Acc: 75.00%
# Epoch [62/200], Train Loss: 0.3587, Validation Loss: 0.2782, Train Acc: 77.60, Validation Acc: 64.58%
# Epoch [63/200], Train Loss: 0.3441, Validation Loss: 0.3158, Train Acc: 80.73, Validation Acc: 75.00%
# Epoch [64/200], Train Loss: 0.3619, Validation Loss: 0.3419, Train Acc: 80.73, Validation Acc: 72.92%
# Epoch [65/200], Train Loss: 0.2951, Validation Loss: 0.3443, Train Acc: 81.77, Validation Acc: 77.08%
# Epoch [66/200], Train Loss: 0.2937, Validation Loss: 0.4784, Train Acc: 83.85, Validation Acc: 77.08%
# Epoch [67/200], Train Loss: 0.4500, Validation Loss: 0.3374, Train Acc: 77.60, Validation Acc: 77.08%
# Epoch [68/200], Train Loss: 0.4575, Validation Loss: 0.2792, Train Acc: 76.04, Validation Acc: 75.00%
# Epoch [69/200], Train Loss: 0.4109, Validation Loss: 0.3273, Train Acc: 80.21, Validation Acc: 72.92%
# Epoch [70/200], Train Loss: 0.3750, Validation Loss: 0.2825, Train Acc: 80.21, Validation Acc: 72.92%
# Epoch [71/200], Train Loss: 0.3567, Validation Loss: 0.2868, Train Acc: 82.29, Validation Acc: 77.08%
# Epoch [72/200], Train Loss: 0.3110, Validation Loss: 0.3097, Train Acc: 85.42, Validation Acc: 75.00%
# Epoch [73/200], Train Loss: 0.3143, Validation Loss: 0.4207, Train Acc: 83.33, Validation Acc: 77.08%
# Epoch [74/200], Train Loss: 0.3402, Validation Loss: 0.2837, Train Acc: 82.29, Validation Acc: 68.75%
# Epoch [75/200], Train Loss: 0.3387, Validation Loss: 0.3880, Train Acc: 79.69, Validation Acc: 77.08%
# Epoch [76/200], Train Loss: 0.3121, Validation Loss: 0.3490, Train Acc: 83.85, Validation Acc: 68.75%
# Epoch [77/200], Train Loss: 0.3014, Validation Loss: 0.3446, Train Acc: 83.85, Validation Acc: 75.00%
# Epoch [78/200], Train Loss: 0.2866, Validation Loss: 0.3272, Train Acc: 84.90, Validation Acc: 79.17%
# Epoch [79/200], Train Loss: 0.2525, Validation Loss: 0.3168, Train Acc: 85.94, Validation Acc: 75.00%
# Epoch [80/200], Train Loss: 0.2648, Validation Loss: 0.3282, Train Acc: 86.46, Validation Acc: 75.00%
# Epoch [81/200], Train Loss: 0.2626, Validation Loss: 0.3068, Train Acc: 87.50, Validation Acc: 70.83%
# Epoch [82/200], Train Loss: 0.3108, Validation Loss: 0.2769, Train Acc: 84.38, Validation Acc: 75.00%
# Epoch [83/200], Train Loss: 0.2392, Validation Loss: 0.4020, Train Acc: 88.02, Validation Acc: 72.92%
# Epoch [84/200], Train Loss: 0.2328, Validation Loss: 0.5337, Train Acc: 90.10, Validation Acc: 68.75%
# Epoch [85/200], Train Loss: 0.3528, Validation Loss: 0.3121, Train Acc: 86.46, Validation Acc: 66.67%
# Epoch [86/200], Train Loss: 0.3151, Validation Loss: 0.4506, Train Acc: 86.46, Validation Acc: 62.50%
# Epoch [87/200], Train Loss: 0.3595, Validation Loss: 0.3046, Train Acc: 81.77, Validation Acc: 70.83%
# Epoch [88/200], Train Loss: 0.3300, Validation Loss: 0.3006, Train Acc: 82.29, Validation Acc: 70.83%
# Epoch [89/200], Train Loss: 0.2704, Validation Loss: 0.3177, Train Acc: 85.42, Validation Acc: 75.00%
# Epoch [90/200], Train Loss: 0.2424, Validation Loss: 0.3298, Train Acc: 90.10, Validation Acc: 68.75%
# Epoch [91/200], Train Loss: 0.2080, Validation Loss: 0.5130, Train Acc: 90.10, Validation Acc: 75.00%
# Epoch [92/200], Train Loss: 0.1640, Validation Loss: 0.4716, Train Acc: 94.79, Validation Acc: 64.58%
# Epoch [93/200], Train Loss: 0.1875, Validation Loss: 0.4798, Train Acc: 91.67, Validation Acc: 66.67%
# Epoch [94/200], Train Loss: 0.1623, Validation Loss: 0.5178, Train Acc: 93.75, Validation Acc: 75.00%
# Epoch [95/200], Train Loss: 0.1631, Validation Loss: 0.4108, Train Acc: 92.19, Validation Acc: 66.67%
# Epoch [96/200], Train Loss: 0.1856, Validation Loss: 0.3561, Train Acc: 92.71, Validation Acc: 64.58%
# Epoch [97/200], Train Loss: 0.1490, Validation Loss: 0.3774, Train Acc: 93.75, Validation Acc: 70.83%
# Epoch [98/200], Train Loss: 0.1647, Validation Loss: 0.6507, Train Acc: 93.23, Validation Acc: 70.83%
# Epoch [99/200], Train Loss: 0.2163, Validation Loss: 0.3468, Train Acc: 88.54, Validation Acc: 70.83%
# Epoch [100/200], Train Loss: 0.1479, Validation Loss: 0.3679, Train Acc: 94.27, Validation Acc: 75.00%
# Epoch [101/200], Train Loss: 0.1715, Validation Loss: 0.4304, Train Acc: 91.67, Validation Acc: 75.00%
# Epoch [102/200], Train Loss: 0.1618, Validation Loss: 0.3367, Train Acc: 92.19, Validation Acc: 58.33%
# Epoch [103/200], Train Loss: 0.3497, Validation Loss: 0.3989, Train Acc: 86.46, Validation Acc: 81.25%
# Epoch [104/200], Train Loss: 0.2996, Validation Loss: 0.2547, Train Acc: 88.54, Validation Acc: 64.58%
# Epoch [105/200], Train Loss: 0.2726, Validation Loss: 0.3383, Train Acc: 90.10, Validation Acc: 77.08%
# Epoch [106/200], Train Loss: 0.2699, Validation Loss: 0.2643, Train Acc: 90.62, Validation Acc: 75.00%
# Epoch [107/200], Train Loss: 0.3144, Validation Loss: 0.3474, Train Acc: 87.50, Validation Acc: 75.00%
# Epoch [108/200], Train Loss: 0.2877, Validation Loss: 0.3327, Train Acc: 90.10, Validation Acc: 72.92%
# Epoch [109/200], Train Loss: 0.3299, Validation Loss: 0.3421, Train Acc: 84.38, Validation Acc: 83.33%
# Epoch [110/200], Train Loss: 0.2733, Validation Loss: 0.2810, Train Acc: 86.98, Validation Acc: 64.58%
# Epoch [111/200], Train Loss: 0.2628, Validation Loss: 0.3366, Train Acc: 89.06, Validation Acc: 75.00%
# Epoch [112/200], Train Loss: 0.1842, Validation Loss: 0.3110, Train Acc: 93.23, Validation Acc: 72.92%
# Epoch [113/200], Train Loss: 0.1577, Validation Loss: 0.3956, Train Acc: 94.79, Validation Acc: 75.00%
# Epoch [114/200], Train Loss: 0.1121, Validation Loss: 0.6504, Train Acc: 96.35, Validation Acc: 70.83%
# Epoch [115/200], Train Loss: 0.1501, Validation Loss: 0.4078, Train Acc: 92.71, Validation Acc: 70.83%
# Epoch [116/200], Train Loss: 0.0872, Validation Loss: 0.6006, Train Acc: 96.35, Validation Acc: 70.83%
# Epoch [117/200], Train Loss: 0.0701, Validation Loss: 0.5299, Train Acc: 98.44, Validation Acc: 75.00%
# Epoch [118/200], Train Loss: 0.0685, Validation Loss: 0.5602, Train Acc: 97.40, Validation Acc: 75.00%
# Epoch [119/200], Train Loss: 0.0399, Validation Loss: 0.7823, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [120/200], Train Loss: 0.1574, Validation Loss: 0.8941, Train Acc: 95.31, Validation Acc: 77.08%
# Epoch [121/200], Train Loss: 0.3287, Validation Loss: 0.5539, Train Acc: 87.50, Validation Acc: 68.75%
# Epoch [122/200], Train Loss: 0.1604, Validation Loss: 0.4055, Train Acc: 92.71, Validation Acc: 75.00%
# Epoch [123/200], Train Loss: 0.1391, Validation Loss: 0.5434, Train Acc: 95.31, Validation Acc: 70.83%
# Epoch [124/200], Train Loss: 0.1436, Validation Loss: 0.3063, Train Acc: 93.23, Validation Acc: 70.83%
# Epoch [125/200], Train Loss: 0.1272, Validation Loss: 0.4384, Train Acc: 94.79, Validation Acc: 75.00%
# Epoch [126/200], Train Loss: 0.0983, Validation Loss: 0.4052, Train Acc: 95.83, Validation Acc: 66.67%
# Epoch [127/200], Train Loss: 0.0959, Validation Loss: 0.4852, Train Acc: 95.83, Validation Acc: 77.08%
# Epoch [128/200], Train Loss: 0.0538, Validation Loss: 0.4748, Train Acc: 98.44, Validation Acc: 70.83%
# Epoch [129/200], Train Loss: 0.0749, Validation Loss: 0.5643, Train Acc: 96.88, Validation Acc: 79.17%
# Epoch [130/200], Train Loss: 0.0460, Validation Loss: 0.5701, Train Acc: 98.44, Validation Acc: 75.00%
# Epoch [131/200], Train Loss: 0.0262, Validation Loss: 0.6491, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [132/200], Train Loss: 0.0299, Validation Loss: 0.6522, Train Acc: 98.96, Validation Acc: 72.92%
# Epoch [133/200], Train Loss: 0.0305, Validation Loss: 0.6428, Train Acc: 98.44, Validation Acc: 72.92%
# Epoch [134/200], Train Loss: 0.0207, Validation Loss: 0.7321, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [135/200], Train Loss: 0.0136, Validation Loss: 0.7106, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [136/200], Train Loss: 0.0157, Validation Loss: 0.7082, Train Acc: 99.48, Validation Acc: 79.17%
# Epoch [137/200], Train Loss: 0.0173, Validation Loss: 0.7461, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [138/200], Train Loss: 0.0293, Validation Loss: 0.7801, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [139/200], Train Loss: 0.0091, Validation Loss: 0.8939, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [140/200], Train Loss: 0.0169, Validation Loss: 0.7677, Train Acc: 99.48, Validation Acc: 72.92%
# Epoch [141/200], Train Loss: 0.0131, Validation Loss: 0.7305, Train Acc: 98.96, Validation Acc: 77.08%
# Epoch [142/200], Train Loss: 0.0168, Validation Loss: 0.7725, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [143/200], Train Loss: 0.0073, Validation Loss: 0.7406, Train Acc: 100.00, Validation Acc: 75.00%
# Epoch [144/200], Train Loss: 0.0086, Validation Loss: 0.7992, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [145/200], Train Loss: 0.0085, Validation Loss: 0.7927, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [146/200], Train Loss: 0.0093, Validation Loss: 0.7981, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [147/200], Train Loss: 0.0096, Validation Loss: 0.8116, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [148/200], Train Loss: 0.0126, Validation Loss: 0.8224, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [149/200], Train Loss: 0.0070, Validation Loss: 0.8023, Train Acc: 100.00, Validation Acc: 75.00%
# Epoch [150/200], Train Loss: 0.0082, Validation Loss: 0.8338, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [151/200], Train Loss: 0.0117, Validation Loss: 0.8179, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [152/200], Train Loss: 0.0091, Validation Loss: 0.8294, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [153/200], Train Loss: 0.0120, Validation Loss: 0.8086, Train Acc: 99.48, Validation Acc: 75.00%
# Epoch [154/200], Train Loss: 0.0066, Validation Loss: 0.9005, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [155/200], Train Loss: 0.0175, Validation Loss: 0.8375, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [156/200], Train Loss: 0.0061, Validation Loss: 0.7854, Train Acc: 100.00, Validation Acc: 79.17%
# Epoch [157/200], Train Loss: 0.0147, Validation Loss: 0.8259, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [158/200], Train Loss: 0.0077, Validation Loss: 0.8164, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [159/200], Train Loss: 0.0090, Validation Loss: 0.8503, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [160/200], Train Loss: 0.0086, Validation Loss: 0.8776, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [161/200], Train Loss: 0.0084, Validation Loss: 0.8746, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [162/200], Train Loss: 0.0187, Validation Loss: 0.8008, Train Acc: 99.48, Validation Acc: 79.17%
# Epoch [163/200], Train Loss: 0.0149, Validation Loss: 0.9093, Train Acc: 98.96, Validation Acc: 68.75%
# Epoch [164/200], Train Loss: 0.0130, Validation Loss: 0.8249, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [165/200], Train Loss: 0.0128, Validation Loss: 0.7657, Train Acc: 99.48, Validation Acc: 79.17%
# Epoch [166/200], Train Loss: 0.0220, Validation Loss: 0.8385, Train Acc: 98.96, Validation Acc: 70.83%
# Epoch [167/200], Train Loss: 0.0094, Validation Loss: 0.7468, Train Acc: 99.48, Validation Acc: 77.08%
# Epoch [168/200], Train Loss: 0.0061, Validation Loss: 0.7445, Train Acc: 100.00, Validation Acc: 79.17%
# Epoch [169/200], Train Loss: 0.0109, Validation Loss: 0.8268, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [170/200], Train Loss: 0.0103, Validation Loss: 0.8625, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [171/200], Train Loss: 0.0072, Validation Loss: 0.8249, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [172/200], Train Loss: 0.0059, Validation Loss: 0.8273, Train Acc: 100.00, Validation Acc: 70.83%
# Epoch [173/200], Train Loss: 0.0075, Validation Loss: 0.8584, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [174/200], Train Loss: 0.0118, Validation Loss: 0.8713, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [175/200], Train Loss: 0.0049, Validation Loss: 0.8152, Train Acc: 100.00, Validation Acc: 68.75%
# Epoch [176/200], Train Loss: 0.0095, Validation Loss: 0.8459, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [177/200], Train Loss: 0.0089, Validation Loss: 0.8585, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [178/200], Train Loss: 0.0099, Validation Loss: 0.8343, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [179/200], Train Loss: 0.0106, Validation Loss: 0.9253, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [180/200], Train Loss: 0.0079, Validation Loss: 0.8278, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [181/200], Train Loss: 0.0083, Validation Loss: 0.8708, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [182/200], Train Loss: 0.0068, Validation Loss: 0.8843, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [183/200], Train Loss: 0.0074, Validation Loss: 0.8447, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [184/200], Train Loss: 0.0072, Validation Loss: 0.9188, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [185/200], Train Loss: 0.0123, Validation Loss: 0.9125, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [186/200], Train Loss: 0.0058, Validation Loss: 0.8399, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [187/200], Train Loss: 0.0100, Validation Loss: 0.8341, Train Acc: 99.48, Validation Acc: 72.92%
# Epoch [188/200], Train Loss: 0.0120, Validation Loss: 0.9328, Train Acc: 98.96, Validation Acc: 68.75%
# Epoch [189/200], Train Loss: 0.0101, Validation Loss: 0.8186, Train Acc: 99.48, Validation Acc: 72.92%
# Epoch [190/200], Train Loss: 0.0154, Validation Loss: 0.7905, Train Acc: 99.48, Validation Acc: 77.08%
# Epoch [191/200], Train Loss: 0.0221, Validation Loss: 0.9250, Train Acc: 98.96, Validation Acc: 66.67%
# Epoch [192/200], Train Loss: 0.0124, Validation Loss: 0.8069, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [193/200], Train Loss: 0.0198, Validation Loss: 0.7453, Train Acc: 98.96, Validation Acc: 81.25%
# Epoch [194/200], Train Loss: 0.0163, Validation Loss: 0.7755, Train Acc: 99.48, Validation Acc: 70.83%
# Epoch [195/200], Train Loss: 0.0068, Validation Loss: 0.8313, Train Acc: 100.00, Validation Acc: 68.75%
# Epoch [196/200], Train Loss: 0.0078, Validation Loss: 0.8231, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [197/200], Train Loss: 0.0101, Validation Loss: 0.7545, Train Acc: 99.48, Validation Acc: 75.00%
# Epoch [198/200], Train Loss: 0.0078, Validation Loss: 0.8217, Train Acc: 99.48, Validation Acc: 68.75%
# Epoch [199/200], Train Loss: 0.0103, Validation Loss: 0.7770, Train Acc: 99.48, Validation Acc: 72.92%
# Epoch [200/200], Train Loss: 0.0062, Validation Loss: 0.7689, Train Acc: 99.48, Validation Acc: 75.00%

# %%
# Gráfica de las curvas de pérdida
plt.figure(figsize=(10, 5))
plt.plot(range(1, out_epochs+1), loss_values, label='Training Loss')
plt.plot(range(1, out_epochs+1), val_loss_values, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss Curves')
plt.grid(True)
plt.show()

# %%
# Gráfica de las curvas de accuracy
plt.figure(figsize=(10, 5))
plt.plot(range(1, out_epochs+1), train_accuracy_values, label='Training Accuracy', color='blue')
plt.plot(range(1, out_epochs+1), val_accuracy_values, label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.title('Training and Validation Accuracy Curves')
plt.grid(True)
plt.show()
